# %% [markdown]
# # contsep toturial

# %%
# %matplotlib notebook

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from pysedm import contsep

# %% [markdown]
# # 1. Load _contsep_ class
# ## It will download PS reference frame.

# %%
date = "20200127"
targetid = "ZTF20aagzchj"

# %%
test_ = contsep.get_spaxels_from_constsep(date, targetid)
# Out:
# THIS ONE 2019-09-06
# THIS ONE 2019-09-06
# downloading BytesIO
# WARNING: FITSFixedWarning: PC001001= -1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC001002= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002001= 0.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: PC002002= 1.
# this form of the PCi_ja keyword is deprecated, use PCi_ja. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2012-01-06T04:23:13' from MJD-OBS'. [astropy.wcs.wcs]

# %% [markdown]
# # 2. Set IFU data "offset" from the reference PS data.
# ### `offset` should be given by hand after visual inspection.
#
# ### !! Will be automated. !!

# %%
# default is offset=(0.0, 0.0)
test_.show_ref_ifu( offset=(0.0, 0.0))
# Out:
# <img src="data:image/png;base64,..." width="600">
# /Users/young-lo/anaconda3/lib/python3.7/site-packages/astrobject-0.8.6-py3.7.egg/astrobject/photometry.py:1513: RuntimeWarning: invalid value encountered in log10

# %%
# For this target, offset=(2.3, -0.3)
test_.show_ref_ifu( offset=(2.3, -0.3))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # 3. Get target OR others (includin host) spaxels

# %% [markdown]
# ## -For the target 'spaxel ids',

# %%
target_spaxel_ids = test_.get_target_spaxels(spaxels_id=True) # spaxels_id=True is default.
target_spaxel_ids
# Out:
# array([537, 546, 563, 573, 582, 589, 592, 599, 608, 617, 624, 634, 643,
#        653, 670])

# %% [markdown]
# ### You can also get target 'spaxel indexes' with _`spaxels_id=False`_.
# ### Spaxel indexes are used in `pysedm`.

# %%
target_spaxel_indexes = test_.get_target_spaxels(spaxels_id=False)
target_spaxel_indexes
# Out:
# array([691, 703, 723, 735, 747, 755, 759, 767, 779, 791, 799, 811, 823,
#        835, 855])

# %% [markdown]
# ## -For others (including host)

# %%
host_spaxel_ids = test_.get_others_spaxels(spaxels_id=True)
host_spaxel_ids
# Out:
# array([ 84,  97, 105, 112, 114, 120, 122, 127, 130, 134, 136, 139, 143,
#        145, 149, 151, 154, 158, 160, 163, 167, 169, 172, 173, 176, 178,
#        181, 182, 184, 187, 189, 191, 193, 196, 197, 200, 202, 205, 206,
#        209, 211, 213, 214, 215, 217, 220, 222, 224, 226, 229, 230, 233,
#        235, 237, 238, 239, 241, 244, 246, 247, 249, 251, 254, 256, 257,
#        259, 261, 263, 264, 265, 267, 270, 272, 273, 274, 276, 279, 281,
#        282, 284, 286, 288, 289, 290, 292, 294, 296, 298, 299, 300, 302,
#        305, 306, 308, 309, 311, 313, 314, 315, 317, 319, 321, 323, 324,
#        325, 328, 331, 332, 334, 335, 337, 339, 341, 343, 344, 346, 348,
#        349, 350, 353, 356, 358, 359, 360, 363, 365, 367, 370, 372, 374,
#        376, 379, 381, 382, 385, 388, 390, 392, 395, 398, 400, 402, 405,
#        407, 408, 411, 414, 416, 417, 418, 421, 424, 426, 428, 431, 434,
#        435, 438, 441, 442, 443, 444, 447, 450, 452, 454, 457, 460, 462,
# ...

# %% [markdown]
# ### 'spaxel indexes' for other source,

# %%
host_spaxel_indexes = test_.get_others_spaxels(spaxels_id=False)
host_spaxel_indexes
# Out:
# array([130, 146, 156, 164, 166, 175, 177, 184, 187, 192, 194, 197, 203,
#        205, 211, 213, 216, 222, 224, 228, 233, 235, 238, 240, 244, 246,
#        249, 251, 254, 257, 259, 263, 265, 268, 270, 274, 276, 279, 281,
#        285, 287, 289, 290, 292, 295, 299, 301, 304, 307, 310, 312, 316,
#        318, 320, 321, 323, 326, 329, 331, 332, 334, 337, 341, 343, 344,
#        346, 349, 351, 352, 354, 357, 361, 363, 364, 366, 369, 372, 374,
#        375, 377, 380, 382, 383, 385, 387, 389, 392, 394, 395, 397, 400,
#        404, 405, 407, 409, 412, 414, 415, 417, 419, 421, 424, 426, 427,
#        429, 432, 436, 437, 439, 441, 444, 447, 449, 451, 452, 456, 458,
#        459, 461, 464, 468, 470, 471, 473, 476, 478, 481, 484, 488, 491,
#        493, 496, 500, 501, 505, 508, 510, 513, 517, 520, 522, 525, 528,
#        532, 534, 537, 540, 542, 544, 545, 549, 552, 554, 557, 560, 564,
#        565, 569, 572, 574, 576, 577, 580, 583, 585, 588, 591, 595, 597,
# ...

# %% [markdown]
# # 4. Check the faintetst contour

# %%
test_.get_target_faintest_contour() # test_.target_contsep_mag ??
# Out:
# 25.5

# %% [markdown]
# # 5. Show the data

# %% [markdown]
# ## -For the cube

# %%
test_.show_ifudata(wcontour=True, wotherspaxel=False, wtargetspaxel=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/young-lo/anaconda3/lib/python3.7/site-packages/pyifu-0.10.6-py3.7.egg/pyifu/tools.py:184: UserWarning: Use the colorbar set_ticks() method instead.

# %% [markdown]
# ### when zoomed

# %%
test_.show_ifudata(wcontour=True, wotherspaxel=False, wtargetspaxel=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### You can see that 25.5 mag is the faintest contour to seperate SN from other sources.

# %% [markdown]
# ### Check with selected spaxels.
#
# Red spaxels are for the target, and black spaxles are for other sources (including host as you can see).

# %%
test_.show_ifudata(wcontour=True, wotherspaxel=True, wtargetspaxel=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### when zoomed

# %%
test_.show_ifudata(wcontour=True, wotherspaxel=True, wtargetspaxel=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### You can see that others spaxels include host and one other sources (next to host).

# %% [markdown]
# ## -For the reference PS data

# %%
test_.show_catdata()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/young-lo/anaconda3/lib/python3.7/site-packages/pysedm-0.26.2-py3.7.egg/pysedm/contsep.py:293: RuntimeWarning: invalid value encountered in log10
#   ax.imshow(np.log10(self.iref.photoref.fakeimage), origin="lower", cmap=mpl.cm.binary)
